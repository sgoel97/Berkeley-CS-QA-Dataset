# %%
from pathlib import Path

# %%
root = Path()
children = list(root.iterdir())
course_dirs = list(
    filter(
        lambda x: x.is_dir() and x.name not in [".git", ".DS_Store"],
        children,
    )
)
course_names = list(map(lambda x: x.name, course_dirs))

# %%
import json


def extract_data_from_json(file_path):
    try:
        # Open and read the JSON file
        with open(file_path, "r", encoding="utf-8") as file:
            data = json.load(file)
            return data
    except FileNotFoundError:
        print(f"The file {file_path} was not found.")
    except json.JSONDecodeError:
        print(f"Error decoding JSON from the file {file_path}.")

# %%
from bs4 import BeautifulSoup
import re


def extract_urls_from_html(file_path):
    # Read the HTML file
    with open(file_path, "r", encoding="utf-8") as file:
        html_content = file.read()

    # Parse the HTML content
    soup = BeautifulSoup(html_content, "html.parser")

    # Find all tags that might contain URLs
    tags_with_urls = soup.find_all(
        ["a", "img", "link", "script"], href=True
    ) + soup.find_all("img", src=True)

    # Regular expression to match URLs
    url_pattern = re.compile(
        r"http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+"
    )

    # Extract and store URLs
    urls = []
    for tag in tags_with_urls:
        # Check and extract 'href' or 'src' attributes
        url = tag.get("href") or tag.get("src")
        if url and url_pattern.match(url):
            urls.append(url)

    return urls


def extract_a_tag_contents(file_path):
    # Read the HTML file
    with open(file_path, "r", encoding="utf-8") as file:
        html_content = file.read()

    # Parse the HTML content
    soup = BeautifulSoup(html_content, "html.parser")

    # Find all <a> tags
    a_tags = soup.find_all("a")

    # Extract and store text content of each <a> tag
    a_tag_contents = [tag.get_text().strip() for tag in a_tags]

    return a_tag_contents


def extract_a_tag_hrefs(file_path):
    # Read the HTML file
    with open(file_path, "r", encoding="utf-8") as file:
        html_content = file.read()

    # Parse the HTML content
    soup = BeautifulSoup(html_content, "html.parser")

    # Find all <a> tags
    a_tags = soup.find_all("a")

    # Extract and store href attribute of each <a> tag
    a_tag_hrefs = [tag.get("href") for tag in a_tags if tag.get("href")]

    return a_tag_hrefs

# %%
exam_web_paths = {}

for course_dir in course_dirs:
    print(f"Processing {course_dir.name}...")
    metadata_path = course_dir / "metadata.json"
    url_path = course_dir / "exam_table.html"
    if url_path.exists():
        hrefs = extract_a_tag_hrefs(url_path)
        hrefs = [
            href
            for href in hrefs
            if "instructor" not in href and "youtube" not in href and "tbp" not in href
        ]
        urls = []
        for path in hrefs:
            if "http" and "://" in path:
                urls.append(path)
            else:
                metadata = extract_data_from_json(metadata_path)
                web_extension = metadata["Exam Prepend"]
                if web_extension[-1] == "/":
                    web_extension = web_extension[:-1]
                if path[0] != "/":
                    path = "/" + path
                path = path.replace("../", "")
                urls.append(web_extension + path)

        urls = [url for url in urls if "instructor" not in url]
        exam_web_paths[course_dir.name] = urls
# Out:
# Processing data101...
# Processing eecs105...
# Processing cs170...
# Processing data100...
# Processing cs184...
# Processing eecs16a...
# Processing cs61b...
# Processing cs61c...
# Processing data8...
# Processing cs164...
# Processing eecs120...
# Processing cs162...
# Processing cs186...
# Processing cs172...
# Processing data102...
# Processing cs188...
# Processing eecs152...
# Processing cs88...
# Processing eecs16b...
# Processing cs189...
# Processing cs10...
# Processing cs174...
# Processing cs61a...
# Processing eecs70...
# Processing cs169...
# Processing cs161...
# Processing cs150...

# %%
import requests


def download_pdf(url, output_path):
    try:
        # Send a GET request to the URL
        response = requests.get(url)

        # Check if the request was successful
        if response.status_code == 200:
            # Write the content of the response to a file
            with open(output_path, "wb") as file:
                file.write(response.content)
            print(f"PDF successfully downloaded to {output_path}")
            return True
        else:
            print(f"Failed to download PDF. Status code: {response.status_code}")
            return False
    except requests.RequestException as e:
        print(f"An error occurred while downloading the PDF: {e}")
        return False

# %%
def write_urls_to_pdfs(urls, class_name):
    # Create the output directory if it doesn't exist
    exams_path = Path(f"./{class_name}/exams")
    if not exams_path.exists():
        exams_path.mkdir(parents=True, exist_ok=True)

    failed_downloads = []
    # Download each PDF
    counter = 0
    for url in urls:
        # Extract the filename from the URL
        filename = url.split("/")[-1]

        if "drive.google.com" in url or "docs.google.com" in url:
            filename = url.split("/")[-2] + ".pdf"

        filename = str(counter) + "_" + filename

        # Download the PDF
        if not (exams_path / filename).exists():
            is_downloaded = download_pdf(url, exams_path / filename)

            if not is_downloaded:
                failed_downloads.append(url)
            else:
                counter += 1

    print(f"\n{class_name} processed successfully\n")
    return failed_downloads

# %%
failed_links = {}
for course_name in sorted(course_names):
    if course_name not in exam_web_paths:
        continue
    urls = exam_web_paths[course_name]
    failed_downloads = write_urls_to_pdfs(urls, course_name)
    failed_links[course_name] = failed_downloads
# Out:
# PDF successfully downloaded to cs10/exams/0_10jmfiZPNDI5uQI05owrF5zL9nlrQ6f7E.pdf
# PDF successfully downloaded to cs10/exams/1_15JVkLNUjx5y3fEbBKaUQRnoLZraag52Y.pdf
# PDF successfully downloaded to cs10/exams/2_1G19VfF5RIOXfHoZR1aqrJYJ5Msf6XXiy.pdf
# PDF successfully downloaded to cs10/exams/3_1KeQzZ3XFwbtJ2dPWtPxe5nHtoQ3tqDpp.pdf
# PDF successfully downloaded to cs10/exams/4_1ihEmzHacBgA9sMtoYj9fKyUJUUrPEqhu.pdf
# PDF successfully downloaded to cs10/exams/5_1-iJmT8cYw3H96Gl-dnUoh9U1swqNnLub9n9bTsrDO9k.pdf
# PDF successfully downloaded to cs10/exams/6_1IDzaiaCJX3mElz37F7FfP7EdtMwJW9Mm.pdf
# PDF successfully downloaded to cs10/exams/7_1vIYrShUM5lpBX1MyRgiPG20T9hjIKIS5.pdf
# PDF successfully downloaded to cs10/exams/8_1t69ewQCLvnLY17BU-z5eFsGlo8CPzJSH05JnYKLbqSI.pdf
# PDF successfully downloaded to cs10/exams/9_1uhJJu_QGLzTyzpKYPHu16IkQYaEWdRxC.pdf
# PDF successfully downloaded to cs10/exams/10_1VFS3_ycsXD3l6QVRSZJK6yOjKOHlB8BE.pdf
# PDF successfully downloaded to cs10/exams/11_xlNPgBWuNx2UDx0iWePuXKVa
# PDF successfully downloaded to cs10/exams/12_opBbNZ71qv41lENJGi52HkzK
# Failed to download PDF. Status code: 401
# Failed to download PDF. Status code: 401
# Failed to download PDF. Status code: 401
# Failed to download PDF. Status code: 401
# Failed to download PDF. Status code: 401
# Failed to download PDF. Status code: 401
# PDF successfully downloaded to cs10/exams/13_folders.pdf
# PDF successfully downloaded to cs10/exams/14_1sCleoTMSogFmyihz1-ns71riunWtl1ir.pdf
# Failed to download PDF. Status code: 401
# Failed to download PDF. Status code: 401
# Failed to download PDF. Status code: 401
mt2-solutions.pdf
# PDF successfully downloaded to cs162/exams/140_sp08-mt1.pdf
# PDF successfully downloaded to cs162/exams/141_sp08-mt1-solutions.pdf
# PDF successfully downloaded to cs162/exams/142_sp08-mt2.pdf
# PDF successfully downloaded to cs162/exams/143_sp08-mt2-solutions.pdf
# PDF successfully downloaded to cs162/exams/144_fa07-mt1.pdf
# PDF successfully downloaded to cs162/exams/145_fa07-mt1-solutions.pdf
# PDF successfully downloaded to cs162/exams/146_fa07-mt2.pdf
# PDF successfully downloaded to cs162/exams/147_fa07-mt2-solutions.pdf
# Failed to download PDF. Status code: 404
# PDF successfully downloaded to cs162/exams/148_fa06-mt1.pdf
# PDF successfully downloaded to cs162/exams/149_fa06-mt1-solutions.pdf
# PDF successfully downloaded to cs162/exams/150_fa06-mt2.pdf
# PDF successfully downloaded to cs162/exams/151_fa06-mt2-solutions.pdf
# PDF successfully downloaded to cs162/exams/152_sp06-mt1.pdf
# PDF successfully downloaded to cs162/exams/153_sp06-mt1-solutions.pdf
# PDF successfully downloaded to cs162/exams/154_sp06-mt2.pdf
# PDF successfully downloaded to cs162/exams/155_sp06-mt2-solutions.pdf
# PDF successfully downloaded to cs162/exams/156_fa05-mt1.pdf
# PDF successfully downloaded to cs162/exams/157_fa05-mt1-solutions.pdf
# PDF successfully downloaded to cs162/exams/158_fa05-mt2.pdf
# PDF successfully downloaded to cs162/exams/159_fa05-mt2-solutions.pdf
# PDF successfully downloaded to cs162/exams/160_fa04-mt1.pdf
# PDF successfully downloaded to cs162/exams/161_fa04-mt1-solutions.txt
# PDF successfully downloaded to cs162/exams/162_fa04-mt1.pdf
# PDF successfully downloaded to cs162/exams/163_sp04-mt1.pdf
# PDF successfully downloaded to cs162/exams/164_sp04-mt1-solutions.pdf
# PDF successfully downloaded to cs162/exams/165_fa03-mt1.pdf
# PDF successfully downloaded to cs162/exams/166_fa03-mt2.pdf
# PDF successfully downloaded to cs162/exams/167_sp03-mt1.pdf
# PDF successfully downloaded to cs162/exams/168_sp03-mt1-solutions.pdf
# PDF successfully downloaded to cs162/exams/169_sp03-mt2.pdf
# PDF successfully downloaded to cs162/exams/170_sp03-mt2-solutions.pdf
# PDF successfully downloaded to cs162/exams/171_fa02-mt1-solutions.txt
# PDF successfully downloaded to cs162/exams/172_fa02-mt2-solutions.txt
# PDF successfully downloaded to cs162/exams/173_sp02-mt1.pdf
# PDF successfully downloaded to cs162/exams/174_sp02-mt1-solutions.pdf
# PDF successfully downloaded to cs162/exams/175_fa01-mt1.pdf
# PDF successfully downloaded to cs162/exams/176_fa01-mt2.pdf
# PDF successfully downloaded to cs162/exams/177_sp01-mt1.pdf
# PDF successfully downloaded to cs162/exams/178_sp01-mt1-solutions.pdf
# Failed to download PDF. Status code: 404
# Failed to download PDF. Status code: 404
# Failed to download PDF. Status code: 404
# Failed to download PDF. Status code: 404
# PDF successfully downloaded to cs162/exams/179_sp00-mt1.pdf
# PDF successfully downloaded to cs162/exams/180_sp00-mt1.pdf
# PDF successfully downloaded to cs162/exams/181_fa99-mt1.pdf
# PDF successfully downloaded to cs162/exams/182_fa99-mt1-solutions.pdf
# PDF successfully downloaded to cs162/exams/183_fa99-mt2.pdf
# PDF successfully downloaded to cs162/exams/184_fa99-mt2-solutions.pdf
# PDF successfully downloaded to cs162/exams/185_sp99-mt1.pdf
# PDF successfully downloaded to cs162/exams/186_sp99-mt1-solutions.pdf
#
# cs162 processed successfully
#
# PDF successfully downloaded to cs164/exams/0_cs164_fa14_mt1_sol.pdf
# PDF successfully downloaded to cs164/exams/1_cs164_fa14_mt2_sol.pdf
# PDF successfully downloaded to cs164/exams/2_cs164_sp14_mt1.pdf
# PDF successfully downloaded to cs164/exams/3_cs164_sp14_mt1_sol.pdf
# PDF successfully downloaded to cs164/exams/4_cs164_sp14_mt2_sol.pdf
# PDF successfully downloaded to cs164/exams/5_cs164_sp10_mt1.pdf
# PDF successfully downloaded to cs164/exams/6_cs164_sp10_mt2.pdf
# PDF successfully downloaded to cs164/exams/7_cs164_sp10_f.pdf
# PDF successfully downloaded to cs164/exams/8_cs164_fa09_mt1.pdf
# PDF successfully downloaded to cs164/exams/9_cs164_fa09_mt1_sol.pdf
# PDF successfully downloaded to cs164/exams/10_cs164_fa09_mt2.pdf
# PDF successfully downloaded to cs164/exams/11_cs164_fa09_mt2_sol.pdf
# PDF successfully downloaded to cs164/exams/12_cs164_sp08_mt1.pdf
# PDF successfully downloaded to cs164/exams/13_cs164_sp08_mt2.pdf
# PDF successfully downloaded to cs164/exams/14_cs164_sp08_f.pdf
# PDF successfully downloaded to cs164/exams/15_cs164_fa07_mt1.pdf
# PDF successfully downloaded to cs164/exams/16_cs164_fa07_mt1_sol.pdf
# PDF successfully downloaded to cs164/exams/17_cs164_fa07_mt2.pdf
# PDF successfully downloaded to cs164/exams/18_cs164_fa07_f.pdf
# PDF successfully downloaded to cs164/exams/19_cs164_sp05_mt1.pdf
# PDF successfully downloaded to cs164/exams/20_cs164_fa04_mt1.pdf
# PDF successfully downloaded to cs164/exams/21_cs164_fa04_mt2.pdf
# PDF successfully downloaded to cs164/exams/22_cs164_sp04_mt1.pdf
# PDF successfully downloaded to cs164/exams/23_cs164_sp04_mt1_sol.pdf
# PDF successfully downloaded to cs164/exams/24_cs164_sp04_mt2.pdf
# PDF successfully downloaded to cs164/exams/25_cs164_fa03_mt1.pdf
# PDF successfully downloaded to cs164/exams/26_cs164_fa03_mt1_sol.pdf
# PDF successfully downloaded to cs164/exams/27_cs164_fa03_mt2.pdf
# PDF successfully downloaded to cs164/exams/28_cs164_fa03_mt2_sol.pdf
# PDF successfully downloaded to cs164/exams/29_cs164_fa03_f.pdf
# PDF successfully downloaded to cs164/exams/30_cs164_fa02_mt1.pdf
# PDF successfully downloaded to cs164/exams/31_cs164_fa02_mt1_sol.txt
# PDF successfully downloaded to cs164/exams/32_cs164_fa02_mt2.pdf
# PDF successfully downloaded to cs164/exams/33_cs164_fa02_mt2_sol.pdf
# PDF successfully downloaded to cs164/exams/34_cs164_sp02_mt1_sol.pdf
# PDF successfully downloaded to cs164/exams/35_cs164_fa01_mt1.pdf
# PDF successfully downloaded to cs164/exams/36_cs164_fa01_mt1_sol.pdf
# PDF successfully downloaded to cs164/exams/37_cs164_fa01_mt2.pdf
# PDF successfully downloaded to cs164/exams/38_cs164_fa01_f.pdf
# PDF successfully downloaded to cs164/exams/39_cs164_sp01_mt1_sol.pdf
# PDF successfully downloaded to cs164/exams/40_cs164_sp01_mt2_sol.pdf
# PDF successfully downloaded to cs164/exams/41_cs164_fa00_mt1.pdf
# PDF successfully downloaded to cs164/exams/42_cs164_fa00_mt1_sol.pdf
# PDF successfully downloaded to cs164/exams/43_cs164_fa00_mt2_sol.pdf
# PDF successfully downloaded to cs164/exams/44_cs164_sp00_mt1.pdf
# PDF successfully downloaded to cs164/exams/45_cs164_sp00_mt1_sol.pdf
# PDF successfully downloaded to cs164/exams/46_cs164_sp00_mt2.pdf
# PDF successfully downloaded to cs164/exams/47_cs164_sp00_f_sol.pdf
# PDF successfully downloaded to cs164/exams/48_cs164_fa99_mt1_sol.pdf
# PDF successfully downloaded to cs164/exams/49_cs164_fa99_mt2.pdf
# PDF successfully downloaded to cs164/exams/50_cs164_sp99_mt1.pdf
# PDF successfully downloaded to cs164/exams/51_cs164_fa98_mt1.pdf
# PDF successfully downloaded to cs164/exams/52_cs164_fa98_mt2.pdf
# PDF successfully downloaded to cs164/exams/53_cs164_sp98_mt1.pdf
# PDF successfully downloaded to cs164/exams/54_cs164_fa97_mt1.pdf
# PDF successfully downloaded to cs164/exams/55_cs164_sp97_mt1.pdf
# PDF successfully downloaded to cs164/exams/56_cs164_fa96_mt1_sol.pdf
# PDF successfully downloaded to cs164/exams/57_cs164_fa96_mt2_sol.pdf
# PDF successfully downloaded to cs164/exams/58_cs164_fa96_f_sol.pdf
# PDF successfully downloaded to cs164/exams/59_cs164_fa95_mt1.txt
# PDF successfully downloaded to cs164/exams/60_cs164_fa95_mt1_sol.pdf
# PDF successfully downloaded to cs164/exams/61_cs164_fa95_mt2_sol.pdf
# PDF successfully downloaded to cs164/exams/62_cs164_fa95_f_sol.pdf
# PDF successfully downloaded to cs164/exams/63_cs164_fa94_mt1.pdf
# PDF successfully downloaded to cs164/exams/64_cs164_fa94_mt1_sol.pdf
# PDF successfully downloaded to cs164/exams/65_cs164_fa94_f_sol.pdf
# PDF successfully downloaded to cs164/exams/66_cs164_sp94_mt2.pdf
# PDF successfully downloaded to cs164/exams/67_cs164_sp93_mt1.pdf
# PDF successfully downloaded to cs164/exams/68_cs164_sp91_mt1.pdf
#
# cs164 processed successfully
#
# PDF successfully downloaded to cs169/exams/0_cs169_fa09_mt1.pdf
# PDF successfully downloaded to cs169/exams/1_cs169_fa05_mt1.pdf
# PDF successfully downloaded to cs169/exams/2_cs169_fa04_mt1.pdf
# PDF successfully downloaded to cs169/exams/3_cs169_fa02_mt1.pdf
#
# cs169 processed successfully
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/samarthgoel/Desktop/Berkeley-CS-QA-Dataset/extract_pdf_from_html.ipynb Cell 8 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/samarthgoel/Desktop/Berkeley-CS-QA-Dataset/extract_pdf_from_html.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> failed_links = {}
#       <a href='vscode-notebook-cell:/Users/samarthgoel/Desktop/Berkeley-CS-QA-Dataset/extract_pdf_from_html.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> for course_name in sorted(course_names):
# ----> <a href='vscode-notebook-cell:/Users/samarthgoel/Desktop/Berkeley-CS-QA-Dataset/extract_pdf_from_html.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a>     urls = exam_web_paths[course_name]
#       <a href='vscode-notebook-cell:/Users/samarthgoel/Desktop/Berkeley-CS-QA-Dataset/extract_pdf_from_html.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a>     failed_downloads = write_urls_to_pdfs(urls, course_name)
#       <a href='vscode-notebook-cell:/Users/samarthgoel/Desktop/Berkeley-CS-QA-Dataset/extract_pdf_from_html.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a>     failed_links[course_name] = failed_downloads
#
# KeyError: 'cs170'

# %%
failed_links
# Out:
# {'cs10': ['https://drive.google.com/file/d/13yRMg8UbTQpS-X7u78j7MhXx9OUhrt82/view',
#   'https://drive.google.com/file/d/1s9n_CoJB5RpaNuUmxPBRxVfXgPOQLWIz/view',
#   'https://drive.google.com/file/d/1CO4AartRWdyw-vIgIS1lzzcqgDSbFB9S/view',
#   'https://drive.google.com/file/d/1G_blwdl9uMn2jTvMjbs7ZVy2Hnc5JJiS/view?usp=sharing',
#   'https://drive.google.com/file/d/1RNL6ChgNuiQ00ngHOBjoVq4I8UEOlzzL/view?usp=sharing',
#   'https://drive.google.com/file/d/1OyR9Zk3q11Xi6xqzQSmq8QdVb3OVHjIW/view?usp=sharing',
#   'https://drive.google.com/file/d/1lSs3TXCJrqB22zgLBByZTI1-5ITqfE9K/view',
#   'https://drive.google.com/file/d/1IXByRzNhPgjmiDDb9kufU4x02Gx2xI9C/view?usp=sharing',
#   'https://drive.google.com/file/d/192pX5wig1Y-2p9OVktznTe0Obf5faode/view?usp=sharing',
#   'https://drive.google.com/file/d/1ZuWs6FWDZAsVCJSDLiPXIfLePhm-eBfT/view?usp=sharing']}

# %%
with open("./failed_download_links.json", "w", encoding="utf-8") as file:
    json.dump(failed_links, file, ensure_ascii=False, indent=4)
